# %% [markdown]
# # Original Text
# This is an actual Airbnb property listing description.
# In this assignment you will preprocess this text follow the usual spaCy pipeline.

# %%
list_description = 'An oasis of tranquility awaits you.<br /><br /><b>The space</b><br />This is a beautiful three story townhouse that will enhance your Santa Monica experience. This airy, light filled, quiet safe haven will be the perfect spot to land after a busy day or just wanting to chill. The first floor, where my guest stays, is a bright, cheerful open space. Lot of natural light. <br /><br />You will be sleeping on a top of the line blow up mattress bed facing a beautiful garden overflowing with flowers to greet you every morning. In addition a peaceful patio area awaits your use. If greater privacy is required Japanese screens are provided. While this area is considered a shared space, you will have it completely to yourself. On the same floor, is the  kitchen fully stocked. Everything you need for a wonderful healthy meal.<br /><br />The 2nd floor is my office and private bath for my guest. The third floor is my quarters. My townhome is large and quite possibly we could not run into one another'

# %% [markdown]
# # Counting tokens and sentences using spaCy
#
# Create a funciton called count_tokens and another function called count_sentences. Use spaCy to count the number of tokens and sentences in this text.

# %%
def countToken(text):
  # enter your code here
  return # enter your return variable here

def countSentence(text):
  # enter your code here
  return # enter your return variable here

# call the above function with the original text and print the number of tokens and sentences.

# %% [markdown]
# # Preprocessing using RegEx and spaCy
# Create a function called preprocess_text. In this function, you receive a text argument, use Regex to clean the original text: change to lower case, remove html tags, special characters and punctuation, digits, single characters, and extra spaces.
#
# Create another function called remove_stopwords. In this function, use spaCy to remove the default stop words.
#
# Create another function called lemmatize. In this function, use spaCy to lemmatize the words.
#
# The output cleaned text should look like the cell below.
#
# Hint: use text = re.sub("<[^>]*>", " ", text) for removing HTML tags.

# %%
def preprocess_text(text):
  # enter your code here
  return # enter return variable here

def remove_stopwords(text):
    # enter your code here
  return # enter return variable here

def lemmatize(text):
    # enter your code here
  return # enter return variable here

# call the above function with the original text and print the cleaned text
# Out:
# 'oasis tranquility await space beautiful story townhouse enhance santa monica experience airy light fill quiet safe haven perfect spot land busy day want chill floor guest stay bright cheerful open space lot natural light sleep line blow mattress bed face beautiful garden overflow flower greet morning addition peaceful patio area await use great privacy require japanese screen provide area consider share space completely floor kitchen fully stock need wonderful healthy meal 2nd floor office private bath guest floor quarter townhome large possibly run'

# %% [markdown]
# # POS

# %% [markdown]
# For every token in the cleaned sentence, print the token text, the lemma tag, the POS tag, the fine-grained TAG tag, and the description of the fine-grained tag. Use f-string to space them out so it's easy to read (the example used a space of {10} here)

# %%
# enter your code here
# Out:
# oasis      oasis      NOUN       NN         noun, singular or mass
# tranquility tranquility NOUN       NN         noun, singular or mass
# awaits     await      VERB       VBZ        verb, 3rd person singular present
# space      space      NOUN       NN         noun, singular or mass
# beautiful  beautiful  ADJ        JJ         adjective (English), other noun-modifier (Chinese)
# story      story      NOUN       NN         noun, singular or mass
# townhouse  townhouse  NOUN       NN         noun, singular or mass
# enhance    enhance    PROPN      NNP        noun, proper singular
# santa      santa      PROPN      NNP        noun, proper singular
# monica     monica     PROPN      NNP        noun, proper singular
# experience experience PROPN      NNP        noun, proper singular
# airy       airy       PROPN      NNP        noun, proper singular
# light      light      NOUN       NN         noun, singular or mass
# filled     fill       VERB       VBD        verb, past tense
# ...

# %% [markdown]
# Provide a frequency list of POS tags from the cleaned text, including the key, the text of key, and the value i.e. frequency.

# %%
# enter your code here
# Out:
# 84. ADJ  : 18
# 86. ADV  : 3
# 92. NOUN : 39
# 96. PROPN: 6
# 100. VERB : 17

# %% [markdown]
# # NER
# Visually display the Dependency Parse for the cleaned text.

# %%
# enter your code here
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c187b7b0e4d546dd9a4fdfbf1ba35e0b-0" class="displacy" width="9180" height="797.0" direction="ltr" style="max-width: none; height: 797.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">oasis</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">tranquility</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="707.0">
# ...

# %% [markdown]
# Show the named entities from the cleaned text.

# %%
# enter your code here
# Out:
# santa monica - GPE - Countries, cities, states
# japanese - NORP - Nationalities or religious or political groups

# %% [markdown]
# Visually display the named entity visualization for the cleaned text.

# %%
# enter your code here
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">oasis tranquility awaits space beautiful story townhouse enhance
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     santa monica
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  experience airy light filled quiet safe haven perfect spot land busy day wanting chill floor guest stays bright cheerful open space lot natural light sleeping line blow mattress bed facing beautiful garden overflowing flowers greet morning addition peaceful patio area awaits use greater privacy required
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     japanese
# ...
